# %%
import pandas as pd

# %%
pd.

# %% [markdown]
# ### 1. Create

# %% [markdown]
# #### 1.1 Create Data from CSV

# %%
df = pd.read_csv('telco_churn.csv')

# %% [markdown]
# #### 1.2 Create DataFrame from Dictionary

# %%
temp_dict = {'col1' : [1,2,3] , 'col2': [5,6,7], 'col3' : [8,9,10]}

# dictdf = pd.DataFrame(tempdict)

dictdf = pd.DataFrame.from_dict(temp_dict)

# %% [markdown]
# ### 2. Read

# %% [markdown]
# #### 2.1 Show Top and Bottom 5 Data

# %%
df.head() # Shows the top 5 rows, we can also specify the number of rows to be shown

df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# #### 2.2 Show Columns and Datatype

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %% [markdown]
# #### 2.3 Summary Statistics

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
df.describe(include = 'object') #By Default describe only includes the integers and float
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %% [markdown]
# #### 2.4 Filtering Columns

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3328     No
# 3329     No
# 3330     No
# 3331    Yes
# 3332     No
# Name: International plan, Length: 3333, dtype: object

# %%
df[['State','International plan']]
# Out:
#      State International plan
# 0       KS                 No
# 1       OH                 No
# 2       NJ                 No
# 3       OH                Yes
# 4       OK                Yes
# ...    ...                ...
# 3328    AZ                 No
# 3329    WV                 No
# 3330    RI                 No
# 3331    CT                Yes
# 3332    TN                 No
#
# [3333 rows x 2 columns]

# %%
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %% [markdown]
# #### 2.5 Filter On Rows

# %%
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
df[df['International plan'] == 'No']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['International plan'] == 'No') & (df['Churn'] == True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 48      ID             119        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3280    AR              76        408                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# #### 2.6 Indexing with iloc

# %%
df.iloc[14] # This will give us the 15th row
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
# df.iloc[row,column]

df.iloc[14,0]
# Out:
# 'IA'

# %%
df.iloc[0:5] #Subset of a Dataframe
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %% [markdown]
# #### 2.7 Indexing with Loc

# %%
state = df.copy()

state.set_index('State', inplace = True)

state.head(2)
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# KS                45.07              197.4             99.0             16.78
# OH                27.47              195.5            103.0             16.62
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# KS                   244.7               91.0               11.01
# OH                   254.4              103.0               11.45
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# ...

# %%
 state.loc['KS'] #LOC is mostly used with Objects/string values
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# KS                 70        408                 No              No
# KS                 92        408                Yes              No
# KS                137        408                 No              No
# KS                132        415                 No              No
# ...               ...        ...                ...             ...
# KS                164        510                 No             Yes
# KS                101        415                 No              No
# KS                127        415                 No             Yes
# KS                 57        415                 No              No
# KS                170        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# ...

# %% [markdown]
# ### 3. Update

# %% [markdown]
# #### 3.1 Dropping Rows

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace = True)

# %% [markdown]
# #### 3.2 Dropping Columns

# %%
df.drop('Churn', axis = 1)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# #### 3.3 Create Calculated Columns

# %%
df['New Column'] = df['Number vmail messages'] + df['Total day minutes']

df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# 1                13.7                 3                3.7
#
# ...

# %% [markdown]
# #### 3.4 Updating an Entire Column

# %%
df['New Column'] = 100

df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# 1                13.7                 3                3.7
#
# ...

# %% [markdown]
# #### 3.5 Updating a single value in a column

# %%
df.iloc[0,-1] = 10

df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# 1                13.7                 3                3.7
#
# ...

# %% [markdown]
# #### 3.6 Condition Based Updating Using Apply

# %%
df['Churn Binary'] = df['Churn'].apply(lambda x: 1 if x==True else 0)

df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3                2.7                     1.0  False
# ...

# %% [markdown]
# ### 4.Delete

# %% [markdown]
# #### 4.1 Output to CSV

# %%
df.to_csv('Output.csv')

# %% [markdown]
# #### 4.2 Output to Json

# %%
df.to_json('Output.json')

# %% [markdown]
# #### 4.3 Output to CSV

# %%
df.to_html('Output.html')

# %% [markdown]
# #### 4.4 Deleting a Dataframe

# %%
del df #This is a python method not related to pandas to delete an objects

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
